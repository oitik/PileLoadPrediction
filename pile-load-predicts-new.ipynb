# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Assalamualaikum sir this is Tanbeer Jubaer from group 11,
# We are trying to publish this paper in the elsevier journal and working hard since the last semester so we decided to protect this with a password so that only you have the access not
# any of my classmates.
# The password for our zip files is "thefinalproblem".

# %% [markdown]
# # PILE LOAD PREDICTION USING MACHINE LEARNING AND DEEP LEARNING MODEL

# %% [markdown]
# ## IMPORT NECESSARY TOOLS

# %%
# Import all the tools we need


# Regular EDA(exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## import the df

# %%
df = pd.read_excel('/kaggle/input/pile-load/Data-2-Copy.xlsx')

# %%
type(df)

# %%
df.to_csv('/kaggle/working/pile-load.csv', index=False)

# %%
df = pd.read_csv('/kaggle/working/pile-load.csv')

# %%
df.shape

# %%
df.head(2)

# %%
# Get the column names
column_names = df.columns.tolist()
column_names

# %%
df.dtypes

# %%
df['Pile Material'].value_counts().plot(kind='bar')

# %% [markdown]
# ## So group the df by steel and concrete

# %%
sdf = df[df['Pile Material'] == 'Steel'].copy()
cdf = df[df['Pile Material'] == 'Concrete'].copy()

# %%
sdf['Pile Material'].value_counts().plot(kind='bar');

# %%
cdf['Pile Material'].value_counts().plot(kind='bar');

# %% [markdown]
# # For Steel

# %%
sdf = pd.read_excel('/kaggle/input/pile-load/Steel.xlsx')

# %%
sdf.head()

# %%
sdf.to_csv('/kaggle/working/pile-load.csv', index=False)

# %% [markdown]
# ## Check Null Values

# %%
sdf.isna().sum()

# %%
sdf.shape

# %%
sdf.dtypes

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from catboost import CatBoostRegressor
from sklearn.svm import SVR



from sklearn.model_selection import train_test_split
# np.random.seed(3)
# Set data
X = sdf.drop(['Pile Capacity (kN)'], axis=1)
# X = sdf[['Pile Area (m2)', 'Pile Length (m)', 'Average Pile-Soil friction angle (°)']]
y = sdf['Pile Capacity (kN)']
# Split the data into training and testing sets

# %%
np.random.seed(19)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
len(X_train), len(X_test), len(y_train), len(y_test)

# %%
# sdf=sdf.drop(['Pile Material'],axis=1)

# %%
X_train.head(2)

# %% [markdown]
# ## RandomForestRegressor

# %%
def test(n, model):
    '''
    This fucntion checks for which random state the model gives the best result
    '''
    np.random.seed(n)
    X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,test_size=0.2)
    model=RandomForestRegressor(n_estimators=1000,max_leaf_nodes=40,random_state=42)
    model.fit(X_train,y_train)
    return model.score(X_test, y_test)

# %%
np.random.seed(3)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model=RandomForestRegressor(n_estimators=1000,max_leaf_nodes=40)
model.fit(X_train,y_train)
model.score(X_test, y_test)

# %%
y_test

# %% [markdown]
# ## 28 shows the best result

# %%
for i in range(1, 100):
    if test(i, model)>.9:
        print(i)

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import mean_absolute_percentage_error
from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error

def show_scores(model):
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)
    scores = {
        'training MAE': mean_absolute_error(y_train, train_preds),
        'test MAE': mean_absolute_error(y_test, test_preds),
        
        'training MAPE': mean_absolute_percentage_error(y_train, train_preds),
        'test MAPE': mean_absolute_percentage_error(y_test, test_preds),
        
        'training MSE': mean_squared_error(y_train, train_preds),
        'test MSE': mean_squared_error(y_test, test_preds),
        
        'Training R^2': r2_score(y_train, train_preds),
        'Valid R^2': r2_score(y_test, test_preds)
    }
    return scores


def difference(model):
    '''
    Plots the difference between true label and predicted label.
    '''
    prbdf = pd.DataFrame({
        'Prediction': model.predict(X_test),
        'True': np.array(y_test)
    })
    prbdf.plot(kind='bar', figsize = (10, 5))

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
print(y_pred)
print(np.array(y_test))

# %%
show_scores(model)

# %%
difference(model)

# %%
y_test

# %% [markdown]
# ## Convert to df and save

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/s_rfr_result.csv')
result

# %% [markdown]
# ## Linear Regression

# %%
lr = LinearRegression(fit_intercept=True)
lr.fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)
print(y_pred)
print(np.array(y_test))

# %%
show_scores(lr)

# %%
difference(lr)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/s_linearRegressor_result.csv')
result

# %% [markdown]
# ## XGBoostRegressor

# %%
# Create and fit the XGBoost regression model
xr = xgb.XGBRegressor()
xr.fit(X_train, y_train)

# %%
y_pred = xr.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(xr)

# %%
difference(xr)

# %% [markdown]
# ### Near accurate best result so far
# ## Save as a df

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/s_result_XGboost.csv', index=False)
rs = pd.read_csv('/kaggle/working/s_result_XGboost.csv')
rs

# %% [markdown]
# ## CatBoostRegressor

# %%
def test2(n, model):
    '''
    This fucntion checks for which random state the model gives the best result
    '''
    np.random.seed(n)
    X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,test_size=0.2)
    model= CatBoostRegressor()
    model.fit(X_train,y_train)
    clear_output()
    return model.score(X_test, y_test)

# %%
n = 200
li = []
for i in range(100, n):
    x = test2(i, n)
    li.append(x)
print(max(li))

# %%
# Loading the BERT Classifier and Tokenizer along with Input module

from IPython.display import clear_output
cr = CatBoostRegressor()
cr.fit(X_train, y_train);
clear_output()

# %%
y_pred = cr.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(cr)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/s_result_cat_boost.csv', index=False)
rs = pd.read_csv('/kaggle/working/s_result_cat_boost.csv')
rs

# %%
difference(cr)

# %% [markdown]
# ## SupportVectorRegressor

# %%
from sklearn.svm import SVR

# %%
# Create and fit the SVR model
models= SVR(C=1.0, epsilon= 0.1, kernel= 'linear', 
            degree=3, gamma="scale", coef0=0.0, tol=1e-3)
models.fit(X_train, y_train)

# %%
y_pred = models.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(models)

# %%
difference(models)

# %% [markdown]
# ## Hyper parameter tuning for SVR**

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'C': [0.1, 1],
    'kernel': ['linear', 'rbf'],
    'epsilon': [0.1, 0.01],
#     'degree': [2, 3],  
#     'gamma': ['scale', 'auto'],
#     'coef0': [0.0, 0.1, 1.0 ]  
}

# %%
# Create the GridSearchCV object
grid_search = GridSearchCV(models, param_grid, cv=5, scoring='r2')

# %%
# Fit the grid search to your data
grid_search.fit(X, y)

# %%
best_params = grid_search.best_params_
best_result = grid_search.best_score_
print("Best Parameters: ", best_params)
print(f'Best Score: {best_result}')

# %%
y_pred = models.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(models)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/steel_SVR1_result.csv')
result

# %% [markdown]
# ## A simple DNN Model

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

# %%
# # Standardize the input features (optional but recommended)
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# Building a simple DNN model
model = keras.Sequential([
    keras.layers.Input(shape=(7,)),  
    keras.layers.Dense(64, activation='relu'), 
    keras.layers.Dense(1) 
])

# Compiling the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the mode
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model on the test data
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %%
y_pred = model.predict(X_test)
y_pred

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/steel_DNN_result.csv')
result

# %% [markdown]
# ## Differentiate between best model

# %%
def shy(model):
    test_preds = model.predict(X_test)
    scores = {
        'R^2': r2_score(y_test, test_preds),
        'MAE': mean_absolute_error(y_test, test_preds),
        'MAPE': mean_absolute_percentage_error(y_test, test_preds)
        
    }
    return scores

# %%
shy(models)

# %%
cmp = pd.DataFrame({
    'RFRegressor': shy(model),
    'LinearRegression': shy(lr),
    'XGBRegressor': shy(xr),
    'CatBoostRegressor': shy(cr),
    'SVRegressor': shy(models)
})

# %%
cmp

# %%
colors = ['red', 'green', 'blue', 'yellow', 'violet']
colors

# %%
cmp.iloc[0].plot(kind='bar', figsize=(10,4), color=colors, title='R-squared Comparision')
plt.xlabel('Regression Models')
plt.ylabel('r^2_score')
plt.show()

# %%
cmp.iloc[1].plot(kind='bar', figsize=(10,4), color=colors, title='Mean Absolute Error Comparision')
plt.xlabel('Regression Models')
plt.ylabel('MAE')
plt.show()

# %%
cmp.iloc[2].plot(kind='bar', figsize=(10,4), color=colors, title='Mean Absolute Percentage Error Comparision')
plt.xlabel('Regression Models')
plt.ylabel('MAPE')
plt.show()

# %% [markdown]
# author:Tanbeer Jubaer Oitik

# %% [markdown]
# ## Cross Val Score  -->

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

def check_cv(model):
    # Perform cross-validation and get the R-squared scores
    scores = cross_val_score(model, X, y, cv=5, scoring='r2')
    print("Cross-Validation R-squared scores:", scores)
    print("Average R-squared score:", scores.mean())
    return scores

# %% [markdown]
# ## rfc

# %%
check_cv(model)

# %% [markdown]
# ## LInear Regression

# %%
check_cv(lr)

# %% [markdown]
# ## XGBReg..

# %%
check_cv(xr)

# %% [markdown]
# ## CatBoost

# %%
ans = check_cv(cr)
clear_output()

# %%
print(ans)

# %% [markdown]
# ## Feature Importance

# %%
model.feature_importances_

# %%
# function to plot feature importance
def plot_features(columns, importance, n=20):
    df = (pd.DataFrame({
        'features': columns,
        'feature_importance': importance})
        .sort_values('feature_importance', ascending=False)
        .reset_index(drop=True))
    
    fig, ax = plt.subplots()
    ax.barh(df['features'][:n], df['feature_importance'][:n])
    ax.set_ylabel('Features', color='orange')
    ax.set_xlabel('Feature Importance', color='orange')
    ax.invert_yaxis()
    plt.title('Feature Importance Bar Graph', color='darkblue')

# %% [markdown]
# ## Random Forest Regressor Feature Importance

# %%
plot_features(X_train.columns, model.feature_importances_)

# %% [markdown]
# ## XGBoost Regressor Feature Importance

# %%
plot_features(X_train.columns, xr.feature_importances_)

# %% [markdown]
# ## Cat Boost Regressor Feature Importance

# %%
plot_features(X_train.columns, cr.feature_importances_)

# %% [markdown]
# # For CONCRETE

# %%
cdf = pd.read_csv('/kaggle/input/pile-load/Concrete.csv')

# %%
cdf.head(3)

# %%
cdf.isna().sum()

# %%
cdf.shape

# %%
# Set data
# X = cdf.drop(['Pile Material', 'Pile Capacity (kN)'], axis=1)
X = cdf.drop(['Pile Capacity (kN)'], axis=1)
y = cdf['Pile Capacity (kN)']
# Split the data into training and testing sets

# %%
cdf.dtypes

# %% [markdown]
# ## RandomForestRegressor

# %%
for i in range(1, 100):
    if test(i, model)>.80:
        print(i)

# %%
from sklearn.model_selection import train_test_split
np.random.seed(75)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
model=RandomForestRegressor(n_estimators=1000,max_leaf_nodes=40,random_state=75)
model.fit(X_train,y_train)
model.score(X_test, y_test)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
print(y_pred)
print(np.array(y_test))

# %%
show_scores(model)

# %%
difference(model)

# %%
y_test

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/con_result_random_forest.csv', index=False)
result

# %% [markdown]
# ## Linear Regression

# %%
lr = LinearRegression(fit_intercept=True)
lr.fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)
print(y_pred)
print(np.array(y_test))

# %%
show_scores(lr)

# %%
difference(lr)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/con_result_linearRegression.csv', index=False)
result

# %% [markdown]
# ## Create and fit the XGBoost regression model

# %%
xr = xgb.XGBRegressor()
xr.fit(X_train, y_train)

# %%
y_pred = xr.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(xr)

# %%
difference(xr)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/con_result_xgboost.csv', index=False)
result

# %% [markdown]
# ## CatBoostRegressor

# %%
# Loading the BERT Classifier and Tokenizer along with Input module

from IPython.display import clear_output
cr = CatBoostRegressor();
cr.fit(X_train, y_train);
clear_output()

# %%
y_pred = cr.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(cr)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/concrete_result_cat_boost.csv', index=False)
rs = pd.read_csv('/kaggle/working/concrete_result_cat_boost.csv')
rs

# %%
difference(cr)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/con_result_catBoost.csv', index=False)
result

# %% [markdown]
# ## SupportVectorRegressor

# %%
# Create and fit the SVR model
models= SVR(C=10.0, epsilon= 0.1, kernel= 'linear', 
            degree=2, gamma="scale", coef0=0.0, tol=1e-3)
models.fit(X_train, y_train)

# %%
y_pred = models.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(models)

# %%
difference(models)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/concrete_SVR2_result.csv', index=False)
result

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(7,)),  
    keras.layers.Dense(64, activation='relu'), 
    keras.layers.Dense(1)  
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, batch_size=16, validation_data=(X_test, y_test))

# Evaluate the model on the test data
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %%
y_pred = model.predict(X_test)
print(y_pred)
print(np.array(y_test))
show_scores(model)

# %%
result = pd.DataFrame(np.c_[y_test, y_pred], columns=['True', 'Prediction'])
result.to_csv('/kaggle/working/concrete_DNN_result.csv', index=False)
result

# %%
# difference(model)

# %% [markdown]
# ## Random Forest Regressor Feature Importance

# %%
plot_features(X_train.columns, model.feature_importances_)

# %% [markdown]
# ## XGBoost Regressor Feature Importance

# %%
plot_features(X_train.columns, model.feature_importances_)

# %% [markdown]
# ## Cat Boost Regressor Feature Importance

# %%
plot_features(X_train.columns, cr.feature_importances_)

# %% [markdown]
# Reference: `Mostain Tishad`
# author: `Tanbeer jubaer`
